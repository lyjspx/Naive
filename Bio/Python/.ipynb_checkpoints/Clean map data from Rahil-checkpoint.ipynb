# %%
import os
os.getcwd()
# Out:
# '/Users/desert/Documents/Scripts/Naive/Bio/Python'

# %%
os.chdir("/Users/desert/Desktop")

# %%
os.getcwd()
# Out:
# '/Users/desert/Desktop'

# %%
import xlrd

# %%
paper2004=xlrd.open_workbook("2004.xlsx","r")

# %%
sheet1A=paper2004.sheet_by_index(0)

# %%
allMarker=[]
for sheet in paper2004.sheets():
    marker=[]
    for row in range(sheet.nrows):
        thisRow=[]
        for col in range(sheet.ncols):
            if(sheet.cell(row,col).value !=''):
                thisRow.append(sheet.cell(row,col).value)
        marker.append(thisRow)
    for one in marker:
        if(len(one)==2):
            allMarker.append([one[0],one[1],sheet.name])
        elif(len(one)>2):
            for i in range(len(one)-1):
                allMarker.append([one[i],one[len(one)-1],sheet.name])

# %%
allMarker
# Out:
# [['Glu-A3', 0.0, '1A'],
#  ['gdm33', 6.0, '1A'],
#  ['gwm136', 12.0, '1A'],
#  ['gwm11', 21.0, '1A'],
#  ['Lr10', 22.0, '1A'],
#  ['cfa2226', 224.0, '1A'],
#  ['cfd15', 25.0, '1A'],
#  ['gwm33', 27.0, '1A'],
#  ['wmc818', 29.0, '1A'],
#  ['wmc336', 35.0, '1A'],
#  ['wmc95', 41.0, '1A'],
#  ['gdm136', 43.0, '1A'],
#  ['barc83', 48.0, '1A'],
#  ['wmc24', 48.0, '1A'],
#  ['gwm357', 52.0, '1A'],
#  ['barc119', 54.0, '1A'],
#  ['gwm164', 56.0, '1A'],
#  ['barc148', 57.0, '1A'],
#  ['cfd59', 57.0, '1A'],
#  ['wmc744', 58.0, '1A'],
#  ['cfd30', 58.0, '1A'],
#  ['barc28', 58.0, '1A'],
#  ['gwm135', 61.0, '1A'],
#  ['wmc278', 62.0, '1A'],
#  ['wmc630', 62.0, '1A'],
#  ['wmc826', 63.0, '1A'],
#  ['wmc611', 63.0, '1A'],
#  ['wmc11', 63.0, '1A'],
#  ['wmc469', 64.0, '1A'],
#  ['wmc183', 65.0, '1A'],
#  ['barc240', 65.0, '1A'],
#  ['cfd22', 65.0, '1A'],
#  ['wmc312', 69.0, '1A'],
#  ['wmc93', 69.0, '1A'],
#  ['cfa2129', 71.0, '1A'],
#  ['wmc9', 72.0, '1A'],
#  ['gwm497', 86.0, '1A'],
#  ['wmc673', 88.0, '1A'],
#  ['wmc51', 90.0, '1A'],
#  ['wmc716', 91.0, '1A'],
#  ['wmc59', 98.0, '1A'],
#  ['barc158', 114.0, '1A'],
#  ['barc17', 115.0, '1A'],
#  ['barc145', 116.0, '1A'],
#  ['cfa2219', 124.0, '1A'],
#  ['gwm99', 126.0, '1A'],
#  ['Gli-B1', 0.0, '1B'],
#  ['Glu-B3', 5.0, '1B'],
#  ['gwm608', 12.0, '1B'],
#  ['gwm550', 14.0, '1B'],
#  ['wmc818', 17.0, '1B'],
#  ['barc128', 18.0, '1B'],
#  ['gwm374.1', 18.0, '1B'],
#  ['wmc49', 19.0, '1B'],
#  ['wmc798', 19.0, '1B'],
#  ['wmc51', 20.0, '1B'],
#  ['wmc619', 21.0, '1B'],
#  ['gwm264', 21.0, '1B'],
#  ['barc60', 23.0, '1B'],
#  ['wmc406', 24.0, '1B'],
#  ['wmc500.1', 24.0, '1B'],
#  ['barc8', 25.0, '1B'],
#  ['gwm413', 26.0, '1B'],
#  ['gdm36', 27.0, '1B'],
#  ['gwm133', 28.0, '1B'],
#  ['gwm33', 28.0, '1B'],
#  ['wmc500.2', 29.0, '1B'],
#  ['wmc128', 30.0, '1B'],
#  ['gdm33', 30.0, '1B'],
#  ['wmc31', 30.0, '1B'],
#  ['gwm494', 30.0, '1B'],
#  ['gdm28', 30.0, '1B'],
#  ['gwm131', 31.0, '1B'],
#  ['gwm498', 31.0, '1B'],
#  ['barc187', 32.0, '1B'],
#  ['wmc419', 32.0, '1B'],
#  ['wmc611', 32.0, '1B'],
#  ['cfd59', 32.0, '1B'],
#  ['cfd2', 33.0, '1B'],
#  ['wmc269', 33.0, '1B'],
#  ['wmc597', 33.0, '1B'],
#  ['gwm273', 33.0, '1B'],
#  ['gwm18', 34.0, '1B'],
#  ['cfd65', 34.0, '1B'],
#  ['gdm136', 34.0, '1B'],
#  ['gwm11', 34.0, '1B'],
#  ['barc137', 34.0, '1B'],
#  ['wmc626', 35.0, '1B'],
#  ['wmc216', 35.0, '1B'],
#  ['wmc213', 36.0, '1B'],
#  ['wmc813', 36.0, '1B'],
#  ['wmc694', 37.0, '1B'],
#  ['wmc156', 37.0, '1B'],
#  ['gwm582', 37.0, '1B'],
#  ['gwm374.2', 38.0, '1B'],
#  ['barc240', 38.0, '1B'],
#  ['barc181', 38.0, '1B'],
#  ['cfa2129', 39.0, '1B'],
#  ['cfd48', 40.0, '1B'],
#  ['gdm101', 42.0, '1B'],
#  ['wmc416', 44.0, '1B'],
#  ['Glu-B1', 44.0, '1B'],
#  ['wmc134', 47.0, '1B'],
#  ['gwm403', 50.0, '1B'],
#  ['wmc206', 60.0, '1B'],
#  ['gwm274', 61.0, '1B'],
#  ['gwm153', 61.0, '1B'],
#  ['barc81', 62.0, '1B'],
#  ['wmc631', 63.0, '1B'],
#  ['wmc766', 63.0, '1B'],
#  ['wmc673', 63.0, '1B'],
#  ['barc188', 63.0, '1B'],
#  ['gwm268', 64.0, '1B'],
#  ['gwm124', 64.0, '1B'],
#  ['cfa2147.1', 75.0, '1B'],
#  ['cfa2147.2', 80.0, '1B'],
#  ['wmc830', 90.0, '1B'],
#  ['wmc719', 90.0, '1B'],
#  ['wmc44', 92.0, '1B'],
#  ['wmc367', 103.0, '1B'],
#  ['barc80', 106.0, '1B'],
#  ['gwm259', 107.0, '1B'],
#  ['wmc728', 110.0, '1B'],
#  ['gwm140', 111.0, '1B'],
#  ['gwm147', 0.0, '1D'],
#  ['Glu-D3', 3.0, '1D'],
#  ['Gli-D1', 4.0, '1D'],
#  ['gdm33', 8.0, '1D'],
#  ['barc149', 14.0, '1D'],
#  ['wmc147', 16.0, '1D'],
#  ['gwm33', 22.0, '1D'],
#  ['wmc432', 23.0, '1D'],
#  ['wmc336', 23.0, '1D'],
#  ['cfd15', 23.0, '1D'],
#  ['cfd61', 26.0, '1D'],
#  ['cfd21', 28.0, '1D'],
#  ['wmc222', 30.0, '1D'],
#  ['cfd92', 33.0, '1D'],
#  ['gwm106', 36.0, '1D'],
#  ['barc119', 44.0, '1D'],
#  ['gwm191', 45.0, '1D'],
#  ['gwm337', 48.0, '1D'],
#  ['wmc489', 49.0, '1D'],
#  ['cfd59', 51.0, '1D'],
#  ['barc99', 51.0, '1D'],
#  ['cfd72', 51.0, '1D'],
#  ['cfd65', 52.0, '1D'],
#  ['wmc429', 53.0, '1D'],
#  ['barc148', 54.0, '1D'],
#  ['gwm608', 54.0, '1D'],
#  ['barc229', 54.0, '1D'],
#  ['gwm458', 55.0, '1D'],
#  ['barc240', 56.0, '1D'],
#  ['wmc339', 56.0, '1D'],
#  ['wmc590', 57.0, '1D'],
#  ['barc169', 58.0, '1D'],
#  ['wmc216', 59.0, '1D'],
#  ['cfd19', 60.0, '1D'],
#  ['wmc36', 73.0, '1D'],
#  ['cfa2129', 73.0, '1D'],
#  ['cfd48', 73.0, '1D'],
#  ['gwm642', 75.0, '1D'],
#  ['gdm126', 75.0, '1D'],
#  ['wmc93', 77.0, '1D'],
#  ['wmc261', 77.0, '1D'],
#  ['wmc673', 77.0, '1D'],
#  ['wmc732', 77.0, '1D'],
#  ['cfd63', 84.0, '1D'],
#  ['wmc813', 87.0, '1D'],
#  ['barc66', 92.0, '1D'],
#  ['gwm232', 107.0, '1D'],
#  ['cfd282', 108.0, '1D'],
#  ['cfa2147', 111.0, '1D'],
#  ['wmc609', 113.0, '1D'],
#  ['wmc405', 115.0, '1D'],
#  ['gdm111', 116.0, '1D'],
#  ['barc62', 117.0, '1D'],
#  ['cfd36', 0.0, '2A'],
#  ['gwm512', 6.0, '2A'],
#  ['barc124', 8.0, '2A'],
#  ['gwm296', 9.0, '2A'],
#  ['wmc667', 10.0, '2A'],
#  ['gwm636', 11.0, '2A'],
#  ['gwm614', 12.0, '2A'],
#  ['gwm497', 13.0, '2A'],
#  ['wmc407', 15.0, '2A'],
#  ['wmc382', 16.0, '2A'],
#  ['barc212', 18.0, '2A'],
#  ['gwm359', 24.0, '2A'],
#  ['wmc728', 28.0, '2A'],
#  ['wmc177', 28.0, '2A'],
#  ['wmc598', 29.0, '2A'],
#  ['gwm71.1', 30.0, '2A'],
#  ['wmc602', 30.0, '2A'],
#  ['wmc149', 31.0, '2A'],
#  ['wmc827', 41.0, '2A'],
#  ['wmc453', 41.0, '2A'],
#  ['wmc522', 45.0, '2A'],
#  ['wmc474', 48.0, '2A'],
#  ['wmc296', 49.0, '2A'],
#  ['wmc792', 49.0, '2A'],
#  ['gwm122', 51.0, '2A'],
#  ['gwm339', 51.0, '2A'],
#  ['gwm515', 52.0, '2A'],
#  ['gwm10', 52.0, '2A'],
#  ['gwm425', 52.0, '2A'],
#  ['gwm275', 52.0, '2A'],
#  ['gwm448', 52.0, '2A'],
#  ['wmc63', 52.0, '2A'],
#  ['gwm95', 53.0, '2A'],
#  ['gwm249', 53.0, '2A'],
#  ['gwm71.2', 54.0, '2A'],
#  ['gwm558', 54.0, '2A'],
#  ['wmc702', 55.0, '2A'],
#  ['wmc644', 56.0, '2A'],
#  ['gdm101', 56.0, '2A'],
#  ['gwm473', 57.0, '2A'],
#  ['wmc794', 57.0, '2A'],
#  ['wmc632', 58.0, '2A'],
#  ['gwm328', 58.0, '2A'],
#  ['wmc455', 59.0, '2A'],
#  ['gwm372', 60.0, '2A'],
#  ['wmc819', 61.0, '2A'],
#  ['wmc261', 62.0, '2A'],
#  ['barc5', 63.0, '2A'],
#  ['cfd6', 65.0, '2A'],
#  ['gwm47', 66.0, '2A'],
#  ['gwm445', 68.0, '2A'],
#  ['wmc109', 71.0, '2A'],
#  ['gwm312', 74.0, '2A'],
#  ['gwm294', 76.0, '2A'],
#  ['cfd168', 85.0, '2A'],
#  ['cfd86', 91.0, '2A'],
#  ['wmc181', 103.0, '2A'],
#  ['gwm356', 126.0, '2A'],
#  ['barc76', 131.0, '2A'],
#  ['wmc658', 140.0, '2A'],
#  ['gwm382', 140.0, '2A'],
#  ['gwm311', 143.0, '2A'],
#  ['Lr16', 0.0, '2B'],
#  ['wmc764', 1.0, '2B'],
#  ['barc45', 4.0, '2B'],
#  ['barc35', 4.0, '2B'],
#  ['wmc661', 5.0, '2B'],
#  ['gwm210', 6.0, '2B'],
#  ['wmc489', 6.0, '2B'],
#  ['wmc382', 8.0, '2B'],
#  ['gwm614', 12.0, '2B'],
#  ['barc124', 15.0, '2B'],
#  ['wmc25', 25.0, '2B'],
#  ['wmc154', 29.0, '2B'],
#  ['wmc243', 30.0, '2B'],
#  ['wmc213', 35.0, '2B'],
#  ['barc200', 37.0, '2B'],
#  ['gwm257', 37.0, '2B'],
#  ['wmc597', 38.0, '2B'],
#  ['wmc257', 39.0, '2B'],
#  ['gwm429', 40.0, '2B'],
#  ['wmc770', 43.0, '2B'],
#  ['barc10', 43.0, '2B'],
#  ['gwm148', 47.0, '2B'],
#  ['gwm410', 49.0, '2B'],
#  ['wmc434', 50.0, '2B'],
#  ['barc13', 50.0, '2B'],
#  ['barc7', 51.0, '2B'],
#  ['barc183', 52.0, '2B'],
#  ['barc55', 55.0, '2B'],
#  ['wmc261', 55.0, '2B'],
#  ['wmc272', 57.0, '2B'],
#  ['gwm630', 58.0, '2B'],
#  ['barc98', 59.0, '2B'],
#  ['wmc474', 59.0, '2B'],
#  ['barc18', 60.0, '2B'],
#  ['wmc344', 60.0, '2B'],
#  ['wmc27', 60.0, '2B'],
#  ['gwm374', 61.0, '2B'],
#  ['barc167', 61.0, '2B'],
#  ['wmc265', 62.0, '2B'],
#  ['wmc179', 62.0, '2B'],
#  ['cfa2278', 62.0, '2B'],
#  ['gwm132', 63.0, '2B'],
#  ['gwm403', 63.0, '2B'],
#  ['gwm319', 63.0, '2B'],
#  ['wmc477', 63.0, '2B'],
#  ['wmc245', 64.0, '2B'],
#  ['wmc592', 64.0, '2B'],
#  ['wmc498', 64.0, '2B'],
#  ['gwm271', 65.0, '2B'],
#  ['gwm55', 66.0, '2B'],
#  ['barc128', 67.0, '2B'],
#  ['gwm129', 69.0, '2B'],
#  ['gwm388', 72.0, '2B'],
#  ['BM134420-239', 73.0, '2B'],
#  ['barc101', 76.0, '2B'],
#  ['wmc441', 77.0, '2B'],
#  ['cfd70', 77.0, '2B'],
#  ['wmc500', 78.0, '2B'],
#  ['wmc51', 78.0, '2B'],
#  ['gwm120', 79.0, '2B'],
#  ['gwm191', 79.0, '2B'],
#  ['cfd73', 82.0, '2B'],
#  ['gwm16', 83.0, '2B'],
#  ['gwm47', 83.0, '2B'],
#  ['gwm501', 85.0, '2B'],
#  ['wmc175', 87.0, '2B'],
#  ['wmc332', 93.0, '2B'],
#  ['wmc627', 94.0, '2B'],
#  ['wmc149', 100.0, '2B'],
#  ['wmc361', 101.0, '2B'],
#  ['wmc317', 106.0, '2B'],
#  ['wmc817', 106.0, '2B'],
#  ['barc159', 109.0, '2B'],
#  ['gwm382', 114.0, '2B'],
#  ['wmc356', 117.0, '2B'],
#  ['gwm526', 120.0, '2B'],
#  ['wmc602', 123.0, '2B'],
#  ['barc124', 0.0, '2D'],
#  ['wmc818', 4.0, '2D'],
#  ['cfd56', 7.0, '2D'],
#  ['cfd65', 7.0, '2D'],
#  ['cfd51', 9.0, '2D'],
#  ['barc90', 10.0, '2D'],
#  ['cfd36', 11.0, '2D'],
#  ['wmc111', 11.0, '2D'],
#  ['wmc25', 18.0, '2D'],
#  ['wmc503', 20.0, '2D'],
#  ['gwm261', 23.0, '2D'],
#  ['gwm296', 24.0, '2D'],
#  ['gwm210', 26.0, '2D'],
#  ['wmc112', 28.0, '2D'],
#  ['gwm455', 32.0, '2D'],
#  ['wmc470', 37.0, '2D'],
#  ['gwm484', 41.0, '2D'],
#  ['gwm122', 41.0, '2D'],
#  ['wmc453', 43.0, '2D'],
#  ['cfd43', 43.0, '2D'],
#  ['barc168', 47.0, '2D'],
#  ['gwm102', 48.0, '2D'],
#  ['cfd2', 59.0, '2D'],
#  ['BE497718-260', 60.0, '2D'],
#  ['gwm515', 63.0, '2D'],
#  ['gwm249', 64.0, '2D'],
#  ['wmc18', 64.0, '2D'],
#  ['gwm30', 64.0, '2D'],
#  ['cfd17', 65.0, '2D'],
#  ['gwm358', 65.0, '2D'],
#  ['barc145', 66.0, '2D'],
#  ['cfd116', 66.0, '2D'],
#  ['wmc630', 66.0, '2D'],
#  ['wmc245', 67.0, '2D'],
#  ['wmc144', 67.0, '2D'],
#  ['cfd193', 69.0, '2D'],
#  ['cfd160', 69.0, '2D'],
#  ['wmc601', 69.0, '2D'],
#  ['wmc797', 71.0, '2D'],
#  ['gwm157', 73.0, '2D'],
#  ['cfd73', 78.0, '2D'],
#  ['cfd233', 79.0, '2D'],
#  ['cfd62', 80.0, '2D'],
#  ['barc228', 81.0, '2D'],
#  ['wmc41', 83.0, '2D'],
#  ['wmc181', 85.0, '2D'],
#  ['cfd16', 85.0, '2D'],
#  ['gwm608', 88.0, '2D'],
#  ['cfd168', 88.0, '2D'],
#  ['wmc243', 90.0, '2D'],
#  ['gwm539', 91.0, '2D'],
#  ['gwm349', 93.0, '2D'],
#  ['cfd239', 94.0, '2D'],
#  ['cfd161', 95.0, '2D'],
#  ['wmc167', 97.0, '2D'],
#  ['wmc175', 99.0, '2D'],
#  ['gwm382', 100.0, '2D'],
#  ['gwm320', 101.0, '2D'],
#  ['barc59', 101.0, '2D'],
#  ['barc159', 102.0, '2D'],
#  ['wmc817', 104.0, '2D'],
#  ['gwm301', 107.0, '2D'],
#  ['wmc11', 0.0, '3A'],
#  ['wmc532', 6.0, '3A'],
#  ['cfd79', 10.0, '3A'],
#  ['gwm369', 14.0, '3A'],
#  ['barc45', 37.0, '3A'],
#  ['gwm2', 37.0, '3A'],
#  ['gwm133', 40.0, '3A'],
#  ['wmc505', 42.0, '3A'],
#  ['gwm32', 44.0, '3A'],
#  ['wmc640', 44.0, '3A'],
#  ['wmc664', 45.0, '3A'],
#  ['gwm5', 45.0, '3A'],
#  ['gwm4', 45.0, '3A'],
#  ['gwm666.1', 45.0, '3A'],
#  ['gwm674', 46.0, '3A'],
#  ['gwm30', 46.0, '3A'],
#  ['wmc651', 46.0, '3A'],
#  ['barc67', 47.0, '3A'],
#  ['wmc388.1', 47.0, '3A'],
#  ['cfd193', 48.0, '3A'],
#  ['gwm403', 49.0, '3A'],
#  ['wmc627', 49.0, '3A'],
#  ['wmc489', 49.0, '3A'],
#  ['cfa2134', 51.0, '3A'],
#  ['cfa2234', 52.0, '3A'],
#  ['wmc527', 53.0, '3A'],
#  ['wmc695', 53.0, '3A'],
#  ['wmc269', 54.0, '3A'],
#  ['wmc428', 56.0, '3A'],
#  ['wmc264', 61.0, '3A'],
#  ['cfa2262', 64.0, '3A'],
#  ['gwm494', 66.0, '3A'],
#  ['gwm162', 67.0, '3A'],
#  ['wmc96', 72.0, '3A'],
#  ['barc69', 73.0, '3A'],
#  ['gwm497', 73.0, '3A'],
#  ['cfa2193', 74.0, '3A'],
#  ['wmc173', 81.0, '3A'],
#  ['cfd2', 82.0, '3A'],
#  ['wmc559', 83.0, '3A'],
#  ['gwm155', 85.0, '3A'],
#  ['wmc153', 87.0, '3A'],
#  ['wmc215', 89.0, '3A'],
#  ['cfa2076', 98.0, '3A'],
#  ['wmc169', 99.0, '3A'],
#  ['wmc388.2', 100.0, '3A'],
#  ['wmc594', 105.0, '3A'],
#  ['gwm666.2', 106.0, '3A'],
#  ['gwm480', 116.0, '3A'],
#  ['barc75', 0.0, '3B'],
#  ['barc180', 0.0, '3B'],
#  ['gwm389', 1.0, '3B'],
#  ['wmc430', 3.0, '3B'],
#  ['wmc674', 4.0, '3B'],
#  ['gwm533.1', 6.0, '3B'],
#  ['barc147', 7.0, '3B'],
#  ['gwm493', 12.0, '3B'],
#  ['barc87', 14.0, '3B'],
#  ['wmc754', 15.0, '3B'],
#  ['cfd79', 15.0, '3B'],
#  ['barc92', 15.0, '3B'],
#  ['wmc597', 30.0, '3B'],
#  ['gwm533.2', 30.0, '3B'],
#  ['wmc500', 32.0, '3B'],
#  ['cfd28', 35.0, '3B'],
#  ['wmc623', 36.0, '3B'],
#  ['wmc808', 39.0, '3B'],
#  ['wmc679', 42.0, '3B'],
#  ['wmc43', 49.0, '3B'],
#  ['wmc51', 49.0, '3B'],
#  ['wmc78', 51.0, '3B'],
#  ['wmc540', 52.0, '3B'],
#  ['gwm566', 54.0, '3B'],
#  ['barc173', 54.0, '3B'],
#  ['gwm264', 56.0, '3B'],
#  ['wmc231', 56.0, '3B'],
#  ['gwm284', 56.0, '3B'],
#  ['barc68', 57.0, '3B'],
#  ['gwm72', 57.0, '3B'],
#  ['wmc815', 57.0, '3B'],
#  ['wmc675', 57.0, '3B'],
#  ['wmc505', 57.0, '3B'],
#  ['wmc777', 58.0, '3B'],
#  ['cfd6', 58.0, '3B'],
#  ['wmc612', 58.0, '3B'],
#  ['wmc625', 59.0, '3B'],
#  ['barc73', 60.0, '3B'],
#  ['wmc693', 60.0, '3B'],
#  ['wmc544', 61.0, '3B'],
#  ['wmc695', 61.0, '3B'],
#  ['wmc446', 61.0, '3B'],
#  ['wmc615', 61.0, '3B'],
#  ['gwm285', 61.0, '3B'],
#  ['gwm274', 61.0, '3B'],
#  ['wmc366', 62.0, '3B'],
#  ['wmc1', 62.0, '3B'],
#  ['wmc533', 62.0, '3B'],
#  ['wmc762', 62.0, '3B'],
#  ['wmc751', 62.0, '3B'],
#  ['gwm644', 63.0, '3B'],
#  ['gwm376', 63.0, '3B'],
#  ['cfd4', 63.0, '3B'],
#  ['gwm77', 65.0, '3B'],
#  ['wmc307', 66.0, '3B'],
#  ['wmc653', 68.0, '3B'],
#  ['gwm107', 68.0, '3B'],
#  ['wmc471', 69.0, '3B'],
#  ['wmc182', 69.0, '3B'],
#  ['barc164', 70.0, '3B'],
#  ['wmc527', 71.0, '3B'],
#  ['wmc418', 72.0, '3B'],
#  ['wmc827', 74.0, '3B'],
#  ['cfa2134', 75.0, '3B'],
#  ['barc145', 76.0, '3B'],
#  ['gwm131', 78.0, '3B'],
#  ['wmc787', 79.0, '3B'],
#  ['gwm4', 81.0, '3B'],
#  ['cfd283', 82.0, '3B'],
#  ['barc229', 89.0, '3B'],
#  ['wmc291', 90.0, '3B'],
#  ['gwm108', 94.0, '3B'],
#  ['cfa2170', 95.0, '3B'],
#  ['barc84', 97.0, '3B'],
#  ['barc206', 97.0, '3B'],
#  ['wmc687', 105.0, '3B'],
#  ['wmc326', 107.0, '3B'],
#  ['barc77', 111.0, '3B'],
#  ['wmc206', 114.0, '3B'],
#  ['gwm299', 123.0, '3B'],
#  ['gwm114', 125.0, '3B'],
#  ['gwm547', 138.0, '3B'],
#  ['gwm181', 139.0, '3B'],
#  ['gwm247', 142.0, '3B'],
#  ['wmc261', 142.0, '3B'],
#  ['wmc274', 142.0, '3B'],
#  ['wmc632', 143.0, '3B'],
#  ['gwm340', 148.0, '3B'],
#  ['cfd35', 0.0, '3D'],
#  ['gwm71', 1.0, '3D'],
#  ['wmc630', 1.0, '3D'],
#  ['wmc11', 1.0, '3D'],
#  ['cfd152', 2.0, '3D'],
#  ['cfd127', 2.0, '3D'],
#  ['gwm161', 3.0, '3D'],
#  ['wmc674', 3.0, '3D'],
#  ['cfd55', 4.0, '3D'],
#  ['cfd141', 5.0, '3D'],
#  ['wmc43', 8.0, '3D'],
#  ['barc128', 10.0, '3D'],
#  ['cfd70.1', 13.0, '3D'],
#  ['cfd79', 15.0, '3D'],
#  ['gwm183', 16.0, '3D'],
#  ['cfd34', 16.0, '3D'],
#  ['gwm2', 18.0, '3D'],
#  ['gwm314', 18.0, '3D'],
#  ['gwm383', 20.0, '3D'],
#  ['gwm664', 21.0, '3D'],
#  ['gwm114', 23.0, '3D'],
#  ['barc42', 23.0, '3D'],
#  ['barc52', 23.0, '3D'],
#  ['wmc492', 24.0, '3D'],
#  ['cfd201', 25.0, '3D'],
#  ['gdm136', 27.0, '3D'],
#  ['gdm99', 28.0, '3D'],
#  ['cfd223', 28.0, '3D'],
#  ['barc68', 29.0, '3D'],
#  ['gwm497', 29.0, '3D'],
#  ['gwm52', 30.0, '3D'],
#  ['gwm456', 30.0, '3D'],
#  ['gwm191', 30.0, '3D'],
#  ['gwm341', 30.0, '3D'],
#  ['wmc741', 31.0, '3D'],
#  ['cfd71', 31.0, '3D'],
#  ['wmc505', 32.0, '3D'],
#  ['cfd2', 32.0, '3D'],
#  ['cfd62', 32.0, '3D'],
#  ['cfd70.2', 32.0, '3D'],
#  ['wmc656', 33.0, '3D'],
#  ['wmc533', 33.0, '3D'],
#  ['cfd193', 33.0, '3D'],
#  ['barc125', 34.0, '3D'],
#  ['cfd4', 34.0, '3D'],
#  ['gwm645', 35.0, '3D'],
#  ['wmc435', 35.0, '3D'],
#  ['cfd9', 36.0, '3D'],
#  ['wmc529', 36.0, '3D'],
#  ['wmc418', 38.0, '3D'],
#  ['wmc631', 39.0, '3D'],
#  ['gwm3', 43.0, '3D'],
#  ['wmc549', 43.0, '3D'],
#  ['cfd211', 44.0, '3D'],
#  ['wmc552', 46.0, '3D'],
#  ['gdm72', 62.0, '3D'],
#  ['barc71', 79.0, '3D'],
#  ['gwm4', 0.0, '4A'],
#  ['wmc516', 2.0, '4A'],
#  ['gwm165', 2.0, '4A'],
#  ['barc206', 4.0, '4A'],
#  ['barc138', 6.0, '4A'],
#  ['wmc420', 7.0, '4A'],
#  ['wmc89', 7.0, '4A'],
#  ['wmc491', 8.0, '4A'],
#  ['wmc680', 8.0, '4A'],
#  ['wmc48', 8.0, '4A'],
#  ['cfd71', 8.0, '4A'],
#  ['wmc173', 9.0, '4A'],
#  ['gwm601', 9.0, '4A'],
#  ['wmc15', 9.0, '4A'],
#  ['wmc446', 9.0, '4A'],
#  ['gwm44', 10.0, '4A'],
#  ['cfa2256', 10.0, '4A'],
#  ['wmc757', 10.0, '4A'],
#  ['wmc96', 11.0, '4A'],
#  ['gwm610', 12.0, '4A'],
#  ['wmc617', 13.0, '4A'],
#  ['gwm397', 18.0, '4A'],
#  ['wmc513', 22.0, '4A'],
#  ['wmc650', 25.0, '4A'],
#  ['barc170', 27.0, '4A'],
#  ['gwm637', 37.0, '4A'],
#  ['wmc468', 38.0, '4A'],
#  ['wmc258', 39.0, '4A'],
#  ['wmc707', 40.0, '4A'],
#  ['wmc161', 46.0, '4A'],
#  ['gwm565', 47.0, '4A'],
#  ['gwm494', 49.0, '4A'],
#  ['cfd257', 51.0, '4A'],
#  ['wmc718', 57.0, '4A'],
#  ['gwm162', 57.0, '4A'],
#  ['wmc760', 58.0, '4A'],
#  ['wmc597', 58.0, '4A'],
#  ['wmc283', 59.0, '4A'],
#  ['cfd88', 60.0, '4A'],
#  ['wmc262', 61.0, '4A'],
#  ['wmc698', 62.0, '4A'],
#  ['wmc500', 67.0, '4A'],
#  ['wmc232', 68.0, '4A'],
#  ['cfd30', 70.0, '4A'],
#  ['barc70', 71.0, '4A'],
#  ['barc78', 71.0, '4A'],
#  ['gwm160', 76.0, '4A'],
#  ['cfd2', 81.0, '4A'],
#  ['wmc776', 82.0, '4A'],
#  ['wmc313', 83.0, '4A'],
#  ['wmc722', 84.0, '4A'],
#  ['wmc497', 85.0, '4A'],
#  ['wmc219', 88.0, '4A'],
#  ['wmc125', 0.0, '4B'],
#  ['Rht-B1', 5.0, '4B'],
#  ['Barc10', 5.0, '4B'],
#  ['wmc47', 10.0, '4B'],
#  ['gwm538', 11.0, '4B'],
#  ['Barc109', 15.0, '4B'],
#  ['gwm6', 16.0, '4B'],
#  ['Barc68', 17.0, '4B'],
#  ['Barc60', 17.0, '4B'],
#  ['wmc413', 17.0, '4B'],
#  ['gwm664', 18.0, '4B'],
#  ['wmc679', 18.0, '4B'],
#  ['wmc652', 19.0, '4B'],
#  ['wmc349', 19.0, '4B'],
#  ['Barc163', 22.0, '4B'],
#  ['wmc310', 23.0, '4B'],
#  ['gwm251', 25.0, '4B'],
#  ['wmc692', 25.0, '4B'],
#  ['cfd39', 26.0, '4B'],
#  ['cfd22', 27.0, '4B'],
#  ['BF484674-297', 28.0, '4B'],
#  ['gwm149', 28.0, '4B'],
#  ['gwm193', 30.0, '4B'],
#  ['gwm192', 30.0, '4B'],
#  ['gwm112', 32.0, '4B'],
#  ['gwm513', 32.0, '4B'],
#  ['gwm165', 32.0, '4B'],
#  ['wmc657', 32.0, '4B'],
#  ['wmc238', 34.0, '4B'],
#  ['gwm66', 34.0, '4B'],
#  ['barc25', 34.0, '4B'],
#  ['gwm113', 35.0, '4B'],
#  ['wmc16', 35.0, '4B'],
#  ['wmc695', 35.0, '4B'],
#  ['wmc419', 35.0, '4B'],
#  ['gwm107', 35.0, '4B'],
#  ['wmc254', 36.0, '4B'],
#  ['cfd2', 36.0, '4B'],
#  ['wmc89', 36.0, '4B'],
#  ['wmc48', 36.0, '4B'],
#  ['wmc826', 36.0, '4B'],
#  ['gwm495', 36.0, '4B'],
#  ['gwm368', 37.0, '4B'],
#  ['gwm540', 37.0, '4B'],
#  ['barc20', 38.0, '4B'],
#  ['wmc491', 38.0, '4B'],
#  ['wmc511', 39.0, '4B'],
#  ['cfd283', 39.0, '4B'],
#  ['wmc546', 43.0, '4B'],
#  ['wmc710', 48.0, '4B'],
#  ['wmc617', 59.0, '4B'],
#  ['wmc617', 0.0, '4D'],
#  ['wmc285', 10.0, '4D'],
#  ['Rht-D1', 12.0, '4D'],
#  ['wmc818', 25.0, '4D'],
#  ['wmc89', 27.0, '4D'],
#  ['wmc720', 27.0, '4D'],
#  ['wmc48', 28.0, '4D'],
#  ['cfd106', 30.0, '4D'],
#  ['cfd160', 30.0, '4D'],
#  ['gwm213', 30.0, '4D'],
#  ['gwm608', 31.0, '4D'],
#  ['wmc52', 31.0, '4D'],
#  ['barc98', 32.0, '4D'],
#  ['cfd193', 32.0, '4D'],
#  ['barc91', 32.0, '4D'],
#  ['wmc473', 33.0, '4D'],
#  ['cfd23', 33.0, '4D'],
#  ['gwm133', 33.0, '4D'],
#  ['cfd71', 33.0, '4D'],
#  ['wmc182', 34.0, '4D'],
#  ['wmc489', 34.0, '4D'],
#  ['wmc457', 35.0, '4D'],
#  ['gwm193', 35.0, '4D'],
#  ['gwm165', 38.0, '4D'],
#  ['wmc33', 43.0, '4D'],
#  ['wmc331', 43.0, '4D'],
#  ['wmc206', 54.0, '4D'],
#  ['wmc399', 54.0, '4D'],
#  ['cfd39', 57.0, '4D'],
#  ['cfd84', 67.0, '4D'],
#  ['wmc622', 70.0, '4D'],
#  ['gwm194', 82.0, '4D'],
#  ['wmc74', 85.0, '4D'],
#  ['wmc825', 87.0, '4D'],
#  ['gwm624', 89.0, '4D'],
#  ['gwm609', 91.0, '4D'],
#  ['barc10', 0.0, '5A'],
#  ['gwm443', 23.0, '5A'],
#  ['wmc47', 23.0, '5A'],
#  ['wmc713', 28.0, '5A'],
#  ['gwm205', 32.0, '5A'],
#  ['gdm109', 33.0, '5A'],
#  ['gwm154', 34.0, '5A'],
#  ['wmc654', 35.0, '5A'],
#  ['cfa2104', 37.0, '5A'],
#  ['BF202040-164', 40.0, '5A'],
#  ['wmc489', 42.0, '5A'],
#  ['cfa2190', 45.0, '5A'],
#  ['wmc51', 45.0, '5A'],
#  ['gwm293', 52.0, '5A'],
#  ['barc197', 53.0, '5A'],
#  ['gwm415', 54.0, '5A'],
#  ['wmc752', 54.0, '5A'],
#  ['wmc150', 55.0, '5A'],
#  ['wmc705', 55.0, '5A'],
#  ['cfa2250', 55.0, '5A'],
#  ['gwm129', 55.0, '5A'],
#  ['barc117', 56.0, '5A'],
#  ['barc56', 57.0, '5A'],
#  ['wmc805', 57.0, '5A'],
#  ['barc186', 57.0, '5A'],
#  ['barc180', 58.0, '5A'],
#  ['gwm304', 59.0, '5A'],
#  ['barc141', 60.0, '5A'],
#  ['gwm186', 62.0, '5A'],
#  ['barc165', 63.0, '5A'],
#  ['wmc446', 63.0, '5A'],
#  ['cfa2121', 64.0, '5A'],
#  ['wmc795', 65.0, '5A'],
#  ['wmc492', 67.0, '5A'],
#  ['gwm96', 67.0, '5A'],
#  ['barc40', 71.0, '5A'],
#  ['gwm156', 73.0, '5A'],
#  ['gwm639', 75.0, '5A'],
#  ['gwm617', 77.0, '5A'],
#  ['wmc415', 80.0, '5A'],
#  ['cfd2', 81.0, '5A'],
#  ['wmc630', 83.0, '5A'],
#  ['wmc475', 84.0, '5A'],
#  ['barc151', 89.0, '5A'],
#  ['wmc388', 92.0, '5A'],
#  ['gwm666', 94.0, '5A'],
#  ['wmc445', 101.0, '5A'],
#  ['cfa2163', 103.0, '5A'],
#  ['cfa2155', 106.0, '5A'],
#  ['cfa2141', 107.0, '5A'],
#  ['wmc96', 110.0, '5A'],
#  ['barc232', 111.0, '5A'],
#  ['cfa2185', 114.0, '5A'],
#  ['wmc110', 128.0, '5A'],
#  ['gwm126', 138.0, '5A'],
#  ['gwm179', 139.0, '5A'],
#  ['cfd39', 139.0, '5A'],
#  ['wmc577', 141.0, '5A'],
#  ['gwm595', 149.0, '5A'],
#  ['wmc524', 151.0, '5A'],
#  ['wmc727', 154.0, '5A'],
#  ['gwm291', 163.0, '5A'],
#  ['gwm410', 166.0, '5A'],
#  ['B1(awns)', 184.0, '5A'],
#  ['cfd5', 0.0, '5B'],
#  ['BE404594-175', 3.0, '5B'],
#  ['wmc773', 8.0, '5B'],
#  ['wmc630', 12.0, '5B'],
#  ['barc240', 12.0, '5B'],
#  ['barc21', 13.0, '5B'],
#  ['cfd60', 14.0, '5B'],
#  ['wmc47', 24.0, '5B'],
#  ['gwm443', 32.0, '5B'],
#  ['wmc728', 37.0, '5B'],
#  ['cfd20', 38.0, '5B'],
#  ['gwm234', 38.0, '5B'],
#  ['wmc149', 39.0, '5B'],
#  ['cfa2121.1', 48.0, '5B'],
#  ['gdm146', 54.0, '5B'],
#  ['wmc813', 55.0, '5B'],
#  ['wmc274', 55.0, '5B'],
#  ['wmc740', 56.0, '5B'],
#  ['gwm159', 57.0, '5B'],
#  ['gwm133', 57.0, '5B'],
#  ['barc4', 58.0, '5B'],
#  ['gwm66', 59.0, '5B'],
#  ['gwm540', 59.0, '5B'],
#  ['gwm191', 59.0, '5B'],
#  ['wmc682', 60.0, '5B'],
#  ['wmc376', 60.0, '5B'],
#  ['wmc386', 60.0, '5B'],
#  ['barc109', 61.0, '5B'],
#  ['gwm544', 61.0, '5B'],
#  ['wmc616', 62.0, '5B'],
#  ['wmc73', 63.0, '5B'],
#  ['cfa2070', 63.0, '5B'],
#  ['wmc363', 63.0, '5B'],
#  ['gwm274', 64.0, '5B'],
#  ['gwm68', 64.0, '5B'],
#  ['gwm67', 65.0, '5B'],
#  ['barc89', 66.0, '5B'],
#  ['gwm335', 68.0, '5B'],
#  ['gwm213', 68.0, '5B'],
#  ['wmc435', 69.0, '5B'],
#  ['wmc745', 71.0, '5B'],
#  ['gwm371', 73.0, '5B'],
#  ['cfd2', 74.0, '5B'],
#  ['gwm499', 75.0, '5B'],
#  ['gwm639', 77.0, '5B'],
#  ['wmc405', 78.0, '5B'],
#  ['wmc759', 79.0, '5B'],
#  ['wmc415', 80.0, '5B'],
#  ['wmc537', 84.0, '5B'],
#  ['gwm554', 89.0, '5B'],
#  ['BQ237037-30', 89.0, '5B'],
#  ['cfd7', 94.0, '5B'],
#  ['wmc289', 112.0, '5B'],
#  ['gwm271', 112.0, '5B'],
#  ['wmc326', 113.0, '5B'],
#  ['wmc75', 114.0, '5B'],
#  ['gwm408', 117.0, '5B'],
#  ['wmc810', 121.0, '5B'],
#  ['gwm604', 124.0, '5B'],
#  ['wmc500', 126.0, '5B'],
#  ['barc140', 127.0, '5B'],
#  ['wmc99', 128.0, '5B'],
#  ['cfa2121.2', 129.0, '5B'],
#  ['barc142', 130.0, '5B'],
#  ['wmc734', 132.0, '5B'],
#  ['gdm116', 133.0, '5B'],
#  ['wmc160', 133.0, '5B'],
#  ['barc232', 134.0, '5B'],
#  ['wmc235', 139.0, '5B'],
#  ['cfd86', 139.0, '5B'],
#  ['wmc28', 139.0, '5B'],
#  ['wmc118', 140.0, '5B'],
#  ['wmc508', 141.0, '5B'],
#  ['wmc640', 148.0, '5B'],
#  ['barc59', 154.0, '5B'],
#  ['wmc430', 154.0, '5B'],
#  ['wmc783', 157.0, '5B'],
#  ['gwm497', 164.0, '5B'],
#  ['wmc258', 173.0, '5B'],
#  ['wmc233', 0.0, '5D'],
#  ['barc130', 4.0, '5D'],
#  ['cfd18', 4.0, '5D'],
#  ['gwm190', 9.0, '5D'],
#  ['cfa2104', 14.0, '5D'],
#  ['cfd189', 14.0, '5D'],
#  ['gwm205', 16.0, '5D'],
#  ['cfd78', 19.0, '5D'],
#  ['wmc150', 21.0, '5D'],
#  ['barc143', 23.0, '5D'],
#  ['cfd81', 24.0, '5D'],
#  ['cfd37', 25.0, '5D'],
#  ['cfd67', 26.0, '5D'],
#  ['gwm358', 26.0, '5D'],
#  ['gwm16', 27.0, '5D'],
#  ['gwm159', 27.0, '5D'],
#  ['wmc608', 28.0, '5D'],
#  ['wmc318', 29.0, '5D'],
#  ['wmc805', 30.0, '5D'],
#  ['gdm153', 32.0, '5D'],
#  ['cfd266', 33.0, '5D'],
#  ['wmc799', 33.0, '5D'],
#  ['cfd40', 35.0, '5D'],
#  ['barc49', 37.0, '5D'],
#  ['gdm138', 38.0, '5D'],
#  ['wmc405', 40.0, '5D'],
#  ['cfd8', 41.0, '5D'],
#  ['gwm583', 43.0, '5D'],
#  ['gdm136', 46.0, '5D'],
#  ['gwm639', 47.0, '5D'],
#  ['gwm182', 49.0, '5D'],
#  ['wmc630', 49.0, '5D'],
#  ['cfd7', 52.0, '5D'],
#  ['cfd3', 53.0, '5D'],
#  ['wmc818', 53.0, '5D'],
#  ['cfd12', 54.0, '5D'],
#  ['cfd57', 55.0, '5D'],
#  ['cfd102', 55.0, '5D'],
#  ['gwm174', 57.0, '5D'],
#  ['cfd26', 57.0, '5D'],
#  ['wmc289', 59.0, '5D'],
#  ['gwm121', 60.0, '5D'],
#  ['gwm271', 61.0, '5D'],
#  ['wmc215', 62.0, '5D'],
#  ['gwm292', 64.0, '5D'],
#  ['wmc264', 65.0, '5D'],
#  ['gwm212', 65.0, '5D'],
#  ['wmc95', 65.0, '5D'],
#  ['wmc434', 66.0, '5D'],
#  ['cfd156', 67.0, '5D'],
#  ['cfd29', 70.0, '5D'],
#  ['wmc788', 75.0, '5D'],
#  ['cfd19', 76.0, '5D'],
#  ['cfd183', 78.0, '5D'],
#  ['wmc636', 80.0, '5D'],
#  ['wmc97', 80.0, '5D'],
#  ['cfd2', 81.0, '5D'],
#  ['barc232', 82.0, '5D'],
#  ['wmc206', 82.0, '5D'],
#  ['cfa2141', 82.0, '5D'],
#  ['gdm63', 82.0, '5D'],
#  ['wmc357', 84.0, '5D'],
#  ['gdm133', 88.0, '5D'],
#  ['cfd86', 91.0, '5D'],
#  ['cfd283', 92.0, '5D'],
#  ['wmc640', 94.0, '5D'],
#  ['cfd10', 98.0, '5D'],
#  ['wmc161', 103.0, '5D'],
#  ['gwm469', 108.0, '5D'],
#  ['wmc96', 108.0, '5D'],
#  ['wmc765', 110.0, '5D'],
#  ['gwm269', 112.0, '5D'],
#  ['barc144', 113.0, '5D'],
#  ['gwm565', 115.0, '5D'],
#  ['gwm272', 116.0, '5D'],
#  ['wmc443', 117.0, '5D'],
#  ['gwm654', 118.0, '5D'],
#  ['Lr1', 120.0, '5D'],
#  ['gwm459', 0.0, '6A'],
#  ['gwm334', 2.0, '6A'],
#  ['barc206', 13.0, '6A'],
#  ['barc23', 23.0, '6A'],
#  ['wmc182', 29.0, '6A'],
#  ['barc37', 35.0, '6A'],
#  ['barc48', 37.0, '6A'],
#  ['barc146', 37.0, '6A'],
#  ['wmc243', 37.0, '6A'],
#  ['wmc753', 37.0, '6A'],
#  ['cfd80', 37.0, '6A'],
#  ['cfd190', 37.0, '6A'],
#  ['wmc398', 37.0, '6A'],
#  ['barc195', 37.0, '6A'],
#  ['wmc672', 38.0, '6A'],
#  ['wmc145', 39.0, '6A'],
#  ['wmc748', 40.0, '6A'],
#  ['wmc786', 40.0, '6A'],
#  ['wmc256', 40.0, '6A'],
#  ['wmc150', 40.0, '6A'],
#  ['wmc807', 41.0, '6A'],
#  ['barc3', 44.0, '6A'],
#  ['wmc684', 46.0, '6A'],
#  ['wmc201', 46.0, '6A'],
#  ['gwm132', 48.0, '6A'],
#  ['gwm570', 51.0, '6A'],
#  ['wmc553', 52.0, '6A'],
#  ['wmc179', 54.0, '6A'],
#  ['gwm169', 83.0, '6A'],
#  ['wmc417', 86.0, '6A'],
#  ['wmc580', 91.0, '6A'],
#  ['gwm427', 93.0, '6A'],
#  ['gwm617', 95.0, '6A'],
#  ['wmc642', 96.0, '6A'],
#  ['wmc621', 15.0, '6A'],
#  ['wmc206', 15.0, '6A'],
#  ['wmc254', 48.0, '6A'],
#  ['wmc59', 56.0, '6A'],
#  ['gwm613', 0.0, '6B'],
#  ['wmc419', 2.0, '6B'],
#  ['wmc486', 3.0, '6B'],
#  ['barc76', 5.0, '6B'],
#  ['wmc487', 9.0, '6B'],
#  ['gwm705', 14.0, '6B'],
#  ['wmc104', 14.0, '6B'],
#  ['gwm132', 14.0, '6B'],
#  ['cfd1', 16.0, '6B'],
#  ['cfd13', 17.0, '6B'],
#  ['gdm113', 27.0, '6B'],
#  ['gwm518', 27.0, '6B'],
#  ['wmc597', 29.0, '6B'],
#  ['wmc494', 29.0, '6B'],
#  ['gwm508', 32.0, '6B'],
#  ['gwm191', 34.0, '6B'],
#  ['wmc737', 35.0, '6B'],
#  ['wmc398', 36.0, '6B'],
#  ['gwm193', 36.0, '6B'],
#  ['gwm133', 37.0, '6B'],
#  ['gwm361', 38.0, '6B'],
#  ['gwm644', 39.0, '6B'],
#  ['wmc397', 40.0, '6B'],
#  ['wmc756', 40.0, '6B'],
#  ['wmc105', 40.0, '6B'],
#  ['gwm88', 41.0, '6B'],
#  ['wmc473', 42.0, '6B'],
#  ['gwm273', 42.0, '6B'],
#  ['wmc179', 42.0, '6B'],
#  ...]

# %%
with open("2004 paper map.csv","w") as outputf:
    for line in allMarker:
        outputf.write(",".join([line[0],str(line[1]),line[2]])+"\n")

# %% [markdown]
# The below belongs to paper 2008

# %%
paper2008=xlrd.open_workbook("2008.xlsx","r")

# %%
allMarker=[]
for sheet in paper2008.sheets():
    marker=[]
    for row in range(sheet.nrows):
        thisRow=[]
        for col in range(sheet.ncols):
            if(sheet.cell(row,col).value !=''):
                thisRow.append(sheet.cell(row,col).value)
        marker.append(thisRow)
    for one in marker:
        if(len(one)==2):
            allMarker.append([one[0],one[1],sheet.name])
        elif(len(one)>2):
            for i in range(len(one)-1):
                allMarker.append([one[i],one[len(one)-1],sheet.name])

# %%
allMarker
# Out:
# [['Xgwm33', 0.0, '1A'],
#  ['Xgwm136', 16.1, '1A'],
#  ['wpPt-2627', 17.4, '1A'],
#  [304745.0, 18.7, '1A'],
#  [377889.0, 19.7, '1A'],
#  ['wPt-6709', 19.7, '1A'],
#  ['wPt-1167', 20.0, '1A'],
#  [304069.0, 20.0, '1A'],
#  ['wPt-8770', 20.0, '1A'],
#  ['wpt-9762', 20.9, '1A'],
#  ['wpt-3870', 23.1, '1A'],
#  ['Xwmc96', 33.7, '1A'],
#  ['Xwmc24', 46.3, '1A'],
#  ['wPt-3698', 49.1, '1A'],
#  ['wPt-4886', 68.9, '1A'],
#  ['Xgwm164', 74.3, '1A'],
#  [304169.0, 109.2, '1A'],
#  [310540.0, 109.8, '1A'],
#  [305651.0, 110.5, '1A'],
#  ['wPt-4668', 131.5, '1A'],
#  ['Xwmc716', 138.6, '1A'],
#  ['Xwmc254', 154.5, '1A'],
#  ['Xgwm99', 155.5, '1A'],
#  ['Xgwm59', 159.4, '1A'],
#  ['Xbarc158', 170.5, '1A'],
#  ['Xwmc85.1', 0.0, '1B'],
#  ['wPt-3763', 1.4, '1B'],
#  [372479.0, 1.4, '1B'],
#  [372373.0, 1.7, '1B'],
#  [372596.0, 2.0, '1B'],
#  [372481.0, 4.2, '1B'],
#  ['wPt-7129', 4.6, '1B'],
#  [312384.0, 7.4, '1B'],
#  ['wPt-8971', 8.0, '1B'],
#  [312781.0, 10.4, '1B'],
#  ['Xwmc500.2', 12.1, '1B'],
#  ['Xwmc230', 14.3, '1B'],
#  ['Xbarc8', 14.6, '1B'],
#  ['wPt-8682', 15.3, '1B'],
#  ['Xgwm11', 23.5, '1B'],
#  ['Xwmc85.2', 26.9, '1B'],
#  ['Xgwm947', 30.9, '1B'],
#  ['Xwmc500.3', 30.9, '1B'],
#  ['wPt-8168', 35.8, '1B'],
#  ['Xgwm131', 38.4, '1B'],
#  ['Xbarc181', 39.2, '1B'],
#  ['Xwmc419', 48.6, '1B'],
#  ['Xcfa2129', 64.4, '1B'],
#  ['wPt-0506', 68.2, '1B'],
#  ['wPt-0202', 68.2, '1B'],
#  ['wPt-3227', 68.2, '1B'],
#  ['Xcfd48', 69.9, '1B'],
#  [304559.0, 73.7, '1B'],
#  [309993.0, 96.3, '1B'],
#  [306730.0, 96.6, '1B'],
#  [304307.0, 96.6, '1B'],
#  [310705.0, 97.6, '1B'],
#  ['Xgwm153', 103.8, '1B'],
#  ['Xbarc81', 104.4, '1B'],
#  [304623.0, 105.1, '1B'],
#  ['Xgwm268', 107.4, '1B'],
#  ['Xbarc188', 108.0, '1B'],
#  ['gwm124', 108.3, '1B'],
#  [305586.0, 108.9, '1B'],
#  ['Xcfa2147', 124.2, '1B'],
#  ['Xwmc44', 129.5, '1B'],
#  ['wPt-1313', 138.5, '1B'],
#  ['wPt-1770', 138.5, '1B'],
#  [304868.0, 146.4, '1B'],
#  [311825.0, 146.7, '1B'],
#  [311653.0, 147.3, '1B'],
#  ['wPt-4497', 148.9, '1B'],
#  ['Xcfd36', 0.0, '2A'],
#  ['wPt-5647', 3.1, '2A'],
#  [304730.0, 3.1, '2A'],
#  [117417.0, 3.1, '2A'],
#  [312299.0, 3.1, '2A'],
#  ['Xbarc212', 3.8, '2A'],
#  ['Xbarc124', 4.8, '2A'],
#  [305562.0, 5.7, '2A'],
#  ['wPt-4533', 5.7, '2A'],
#  ['wPt-9624', 18.0, '2A'],
#  ['wPt-7626', 18.0, '2A'],
#  ['Xwmc177', 36.2, '2A'],
#  ['Xgwm1198', 45.0, '2A'],
#  ['wPt-7026', 46.0, '2A'],
#  ['Xbarc353.1', 0.0, '2A'],
#  ['Xgwm372', 0.7, '2A'],
#  ['Xcfa2164.2', 0.7, '2A'],
#  [305426.0, 1.0, '2A'],
#  ['Xgwm1045', 2.1, '2A'],
#  ['Xcfa2263', 2.4, '2A'],
#  ['Xgwm294', 38.4, '2A'],
#  ['wPt-0015', 55.6, '2A'],
#  ['wPt-3865', 55.6, '2A'],
#  ['Xgwm311', 73.6, '2A'],
#  [304805.0, 75.6, '2A'],
#  ['wPt-9797', 76.3, '2A'],
#  [304972.0, 76.9, '2A'],
#  [305261.0, 78.1, '2A'],
#  [310911.0, 78.1, '2A'],
#  [305752.0, 78.8, '2A'],
#  ['wPt-5887', 79.1, '2A'],
#  ['wPt-3281', 79.5, '2A'],
#  ['wPt-1499', 79.5, '2A'],
#  ['Xgwm265', 79.5, '2A'],
#  ['wPt-7739', 81.0, '2A'],
#  [117438.0, 0.0, '2B'],
#  [117413.0, 0.0, '2B'],
#  ['wPt-2106', 3.0, '2B'],
#  [310258.0, 4.0, '2B'],
#  ['Xwmc243', 16.6, '2B'],
#  [312549.0, 17.3, '2B'],
#  [305161.0, 18.0, '2B'],
#  ['wPt-5672', 48.1, '2B'],
#  ['wPt-5556', 56.1, '2B'],
#  ['wPt-4125', 56.4, '2B'],
#  ['wpt-7757', 59.9, '2B'],
#  ['wPt8583', 63.7, '2B'],
#  ['Xgwm148', 64.4, '2B'],
#  ['wPt-0408', 66.0, '2B'],
#  ['wPt-6477', 72.9, '2B'],
#  ['xbarc183', 0.0, '2B'],
#  ['wPt-1140', 2.4, '2B'],
#  ['Xbarc101.1', 5.8, '2B'],
#  ['Xgwm1249', 7.0, '2B'],
#  [310191.0, 8.0, '2B'],
#  [312678.0, 9.7, '2B'],
#  ['wPt-9350', 12.8, '2B'],
#  [303877.0, 12.8, '2B'],
#  ['wPt-8460', 14.0, '2B'],
#  [305223.0, 14.4, '2B'],
#  [304657.0, 18.1, '2B'],
#  ['Xwmc332', 28.8, '2B'],
#  ['wPt-9257', 33.3, '2B'],
#  ['wPt-0697', 33.3, '2B'],
#  [304741.0, 57.6, '2B'],
#  [305231.0, 59.3, '2B'],
#  [312481.0, 59.9, '2B'],
#  ['wPt-2135', 59.9, '2B'],
#  ['wPt7360', 59.9, '2B'],
#  ['wPt-3378', 60.2, '2B'],
#  ['wPt-0049', 60.5, '2B'],
#  [306485.0, 60.5, '2B'],
#  [311192.0, 60.5, '2B'],
#  [305353.0, 60.8, '2B'],
#  ['Xwmc149', 63.2, '2B'],
#  ['wPt-4892', 64.2, '2B'],
#  ['wPt-2929', 64.2, '2B'],
#  [310437.0, 66.6, '2B'],
#  ['Xbarc310', 0.0, '3A'],
#  [117472.0, 10.9, '3A'],
#  [304419.0, 12.3, '3A'],
#  [312040.0, 12.3, '3A'],
#  ['wPt-6854', 16.7, '3A'],
#  ['Xbarc12', 16.7, '3A'],
#  ['wPt-9369', 16.7, '3A'],
#  ['wPt-7992', 16.7, '3A'],
#  [309965.0, 16.7, '3A'],
#  [312000.0, 19.6, '3A'],
#  [311707.0, 21.3, '3A'],
#  ['Xbarc45', 0.0, '3A'],
#  ['Xcfa2163.1', 8.4, '3A'],
#  ['Xwmc505.1', 10.6, '3A'],
#  ['Xcfa2234', 17.1, '3A'],
#  ['Xwmc664', 18.7, '3A'],
#  ['Xcfa2262', 50.8, '3A'],
#  [306882.0, 53.8, '3A'],
#  [306530.0, 55.6, '3A'],
#  [312342.0, 55.6, '3A'],
#  [304884.0, 57.6, '3A'],
#  ['wPt-3816', 76.8, '3A'],
#  [305013.0, 76.8, '3A'],
#  ['wPt-1562', 76.8, '3A'],
#  ['Xbarc69', 81.0, '3A'],
#  ['Xbarc51', 111.4, '3A'],
#  ['wPt-6422', 112.9, '3A'],
#  ['wPt-5133', 114.5, '3A'],
#  [305077.0, 114.5, '3A'],
#  ['Xgwm1038', 116.0, '3A'],
#  [305434.0, 131.3, '3A'],
#  [311478.0, 131.7, '3A'],
#  ['wPt-0398', 133.7, '3A'],
#  [3109962.0, 134.3, '3A'],
#  ['Xgwm1034', 0.0, '3B'],
#  ['wPt-7984', 0.7, '3B'],
#  ['wPt-3921', 1.6, '3B'],
#  [311004.0, 1.6, '3B'],
#  ['wPt-1867', 1.6, '3B'],
#  [305711.0, 1.6, '3B'],
#  [305799.0, 1.6, '3B'],
#  ['Xbarc133', 3.2, '3B'],
#  ['wPt-1081', 7.3, '3B'],
#  ['wPt2757', 7.3, '3B'],
#  ['Xgwm493', 10.3, '3B'],
#  ['wPt-0302', 11.7, '3B'],
#  ['wPt-3536', 12.0, '3B'],
#  ['Xbarcc102', 14.1, '3B'],
#  [304576.0, 17.8, '3B'],
#  [306336.0, 18.2, '3B'],
#  ['Xwmc500.1', 22.6, '3B'],
#  ['Xwmc43', 36.2, '3B'],
#  [306846.0, 39.1, '3B'],
#  [306646.0, 41.6, '3B'],
#  [310995.0, 42.2, '3B'],
#  [311948.0, 42.9, '3B'],
#  ['wPt-6239', 42.9, '3B'],
#  ['wPt-1191', 44.4, '3B'],
#  ['wPt-2013', 44.7, '3B'],
#  ['wPt-4476', 44.7, '3B'],
#  ['Xwmc505.2', 59.6, '3B'],
#  ['wPt-9432', 65.3, '3B'],
#  ['wPt-9510', 65.3, '3B'],
#  ['wPt-5390', 69.5, '3B'],
#  [304397.0, 116.3, '3B'],
#  ['Xksum157', 124.6, '3B'],
#  ['wPt0384', 129.9, '3B'],
#  ['wPt-0036', 129.9, '3B'],
#  [312433.0, 134.3, '3B'],
#  [304611.0, 140.0, '3B'],
#  ['wPt-2698', 140.7, '3B'],
#  ['Xcfa2170', 146.7, '3B'],
#  [306863.0, 164.6, '3B'],
#  [311544.0, 164.9, '3B'],
#  [117370.0, 165.5, '3B'],
#  ['wPt-4401', 166.1, '3B'],
#  ['wpt-4194', 173.2, '3B'],
#  ['wPt-8559', 173.5, '3B'],
#  ['wPt-5947', 173.8, '3B'],
#  ['Xgwm299', 183.9, '3B'],
#  [304574.0, 185.4, '3B'],
#  [304874.0, 186.5, '3B'],
#  ['wPt-7705', 187.4, '3B'],
#  ['wPt8959', 187.4, '3B'],
#  [310527.0, 195.4, '3B'],
#  [312331.0, 195.7, '3B'],
#  [310378.0, 195.7, '3B'],
#  [305044.0, 195.7, '3B'],
#  [310712.0, 195.7, '3B'],
#  [305246.0, 195.7, '3B'],
#  ['wPt-2559', 195.7, '3B'],
#  ['wPt-5072', 196.0, '3B'],
#  ['wPt-7614', 196.0, '3B'],
#  ['wPt-3165', 196.3, '3B'],
#  ['wPt-9488', 199.6, '3B'],
#  [306702.0, 199.6, '3B'],
#  ['Xgwm247', 202.7, '3B'],
#  ['Xgwm340', 203.1, '3B'],
#  ['Xwmc161', 0.0, '4A'],
#  [306405.0, 3.0, '4A'],
#  [305151.0, 32.8, '4A'],
#  [311417.0, 33.8, '4A'],
#  ['wPt-7939', 34.8, '4A'],
#  ['wPt-9414', 35.4, '4A'],
#  ['wPt-2542', 37.1, '4A'],
#  ['wPt-5249', 37.7, '4A'],
#  [306320.0, 43.9, '4A'],
#  ['Xwmc262', 45.9, '4A'],
#  ['Xcfd31', 48.7, '4A'],
#  [310344.0, 53.8, '4A'],
#  [310254.0, 64.5, '4A'],
#  ['Xwmc500.4', 65.8, '4A'],
#  [303948.0, 68.7, '4A'],
#  [306332.0, 68.7, '4A'],
#  ['wPt-9196', 69.1, '4A'],
#  [304194.0, 69.1, '4A'],
#  ['wPt-2794', 73.3, '4A'],
#  ['wPt-8167', 74.2, '4A'],
#  ['wPt-8886', 74.2, '4A'],
#  ['wPt-3108', 74.2, '4A'],
#  ['wPt-8271', 74.2, '4A'],
#  [305944.0, 74.2, '4A'],
#  ['wPt-7821', 74.9, '4A'],
#  ['wPt6502', 74.9, '4A'],
#  ['wPt-3506', 75.5, '4A'],
#  ['Xbarc78', 76.4, '4A'],
#  ['wPt-7354', 78.0, '4A'],
#  ['wPt-9418', 82.1, '4A'],
#  ['wPt-1155', 82.1, '4A'],
#  ['wPt-4424', 82.1, '4A'],
#  ['wPt-4634', 82.1, '4A'],
#  ['Xwmc219', 82.1, '4A'],
#  [312857.0, 82.7, '4A'],
#  [305697.0, 82.7, '4A'],
#  [117411.0, 82.7, '4A'],
#  [306489.0, 82.7, '4A'],
#  [305449.0, 83.3, '4A'],
#  ['wPt-4620', 84.6, '4A'],
#  [312442.0, 84.6, '4A'],
#  [305829.0, 84.6, '4A'],
#  [311547.0, 84.9, '4A'],
#  ['Xwmc313', 88.0, '4A'],
#  ['Xmc710', 0.0, '4B'],
#  ['Xgwm1278', 20.6, '4B'],
#  ['Xgwm368', 39.9, '4B'],
#  [305166.0, 46.8, '4B'],
#  ['Xbarc20', 48.6, '4B'],
#  ['Xgwm856', 48.6, '4B'],
#  [306232.0, 54.2, '4B'],
#  ['wPt-0872', 54.8, '4B'],
#  [310048.0, 60.3, '4B'],
#  ['Xbarc340.1', 62.2, '4B'],
#  ['Xgwm513', 63.0, '4B'],
#  ['wPt-2273', 75.9, '4B'],
#  ['wPt-2994', 76.2, '4B'],
#  ['Xgwm165', 77.1, '4B'],
#  ['Xgwm1084', 93.4, '4B'],
#  ['Xgwm6', 109.7, '4B'],
#  [304279.0, 116.7, '4B'],
#  ['Xgwm443.1', 0.0, '5A'],
#  ['Xgwm154', 0.7, '5A'],
#  [311017.0, 3.4, '5A'],
#  ['Xbarc303', 22.2, '5A'],
#  ['Xgwm293', 25.6, '5A'],
#  ['Xbarc117', 29.4, '5A'],
#  ['Xgwm1570', 64.0, '5A'],
#  ['Xcfa2163.2', 78.2, '5A'],
#  ['Xcfa2141', 79.9, '5A'],
#  ['Xgwm126', 103.5, '5A'],
#  ['Xgwm595', 106.0, '5A'],
#  ['Xwmc524', 106.7, '5A'],
#  ['wPt-9006', 0.0, '5B'],
#  ['Xgwm443.2', 10.3, '5B'],
#  [312934.0, 12.0, '5B'],
#  [117474.0, 18.4, '5B'],
#  ['wPt-1261', 23.4, '5B'],
#  ['Xgwm234', 30.5, '5B'],
#  ['Xwmc376', 48.3, '5B'],
#  ['Xgwm112.2', 52.8, '5B'],
#  ['Xgwm639', 67.2, '5B'],
#  ['Xwmc99', 95.5, '5B'],
#  ['Xbarc142', 97.1, '5B'],
#  ['Xgwm1246', 98.4, '5B'],
#  [310330.0, 105.8, '5B'],
#  [311891.0, 110.6, '5B'],
#  ['Xbarc243', 132.5, '5B'],
#  [305419.0, 144.5, '5B'],
#  [312416.0, 145.4, '5B'],
#  ['wPt-4723', 146.4, '5B'],
#  [310183.0, 0.0, '6A'],
#  [304723.0, 0.7, '6A'],
#  [305050.0, 1.6, '6A'],
#  ['wPt-9306', 1.6, '6A'],
#  ['wPt-1377', 1.9, '6A'],
#  ['wPt-9075', 1.9, '6A'],
#  ['wPt-7475', 2.2, '6A'],
#  ['Xgwm459', 2.2, '6A'],
#  ['wPt-4017', 2.2, '6A'],
#  ['wPt-73330', 2.5, '6A'],
#  ['wPt-3468', 2.8, '6A'],
#  ['wPt-2636', 2.8, '6A'],
#  [311946.0, 2.8, '6A'],
#  [305815.0, 2.8, '6A'],
#  ['wPt-0864', 2.8, '6A'],
#  [117493.0, 2.8, '6A'],
#  ['wPt-7938', 2.8, '6A'],
#  ['wPt-4016', 2.8, '6A'],
#  [306534.0, 2.8, '6A'],
#  [310475.0, 5.5, '6A'],
#  ['wPt-7486', 12.3, '6A'],
#  ['wPt-0259', 13.3, '6A'],
#  ['Xgwm1009', 18.0, '6A'],
#  ['Xbarc23', 18.3, '6A'],
#  ['wPt-3091', 25.1, '6A'],
#  ['wPt-8833', 25.4, '6A'],
#  ['wPt-0357', 25.7, '6A'],
#  ['wPt-7599', 27.9, '6A'],
#  ['wPt-3202', 28.2, '6A'],
#  [310507.0, 32.7, '6A'],
#  [306122.0, 32.7, '6A'],
#  ['wPt-2077', 40.4, '6A'],
#  ['Xgw,132.1', 57.5, '6A'],
#  ['Xgwm356', 64.0, '6A'],
#  ['Xcfa164.1', 76.5, '6A'],
#  [303843.0, 101.4, '6A'],
#  [311561.0, 105.8, '6A'],
#  ['Xbarc353B', 112.6, '6A'],
#  ['Xgwm169', 118.4, '6A'],
#  ['Xgwm427', 141.6, '6A'],
#  ['wPt-5696', 144.9, '6A'],
#  ['wPt-3247', 145.2, '6A'],
#  ['wPt-1661', 146.2, '6A'],
#  ['XDuPw167', 146.2, '6A'],
#  ['wPt-1642', 147.2, '6A'],
#  [305232.0, 148.5, '6A'],
#  [304589.0, 149.2, '6A'],
#  [306753.0, 149.2, '6A'],
#  [306249.0, 151.3, '6A'],
#  ['Xgwm613', 0.0, '6B'],
#  ['wPt-0351', 15.9, '6B'],
#  [306315.0, 16.9, '6B'],
#  ['wPt-1852', 16.9, '6B'],
#  ['wPt-0245', 16.9, '6B'],
#  [310714.0, 16.9, '6B'],
#  ['wPt-3304', 16.9, '6B'],
#  [309986.0, 16.9, '6B'],
#  ['wPt-3116', 16.9, '6B'],
#  ['wPt-2991', 16.9, '6B'],
#  ['wPt-6994', 16.9, '6B'],
#  ['wPt-7662', 17.5, '6B'],
#  [304668.0, 17.5, '6B'],
#  [311089.0, 17.5, '6B'],
#  ['wPt-8239', 17.5, '6B'],
#  [311645.0, 18.1, '6B'],
#  ['wPt-6988', 18.1, '6B'],
#  [304934.0, 18.1, '6B'],
#  [311892.0, 18.1, '6B'],
#  [306099.0, 18.7, '6B'],
#  [312130.0, 18.7, '6B'],
#  ['wPt-3130', 18.7, '6B'],
#  ['wPt-4720', 18.7, '6B'],
#  ['wPt-4386', 18.7, '6B'],
#  ['wPt-9990', 18.7, '6B'],
#  ['wPt-7150', 18.7, '6B'],
#  [310028.0, 18.7, '6B'],
#  [306420.0, 20.5, '6B'],
#  ['Xwmc486', 22.1, '6B'],
#  [305163.0, 39.9, '6B'],
#  [303952.0, 41.7, '6B'],
#  [306288.0, 41.7, '6B'],
#  [311566.0, 43.2, '6B'],
#  [304248.0, 46.3, '6B'],
#  [117418.0, 46.6, '6B'],
#  [312917.0, 46.9, '6B'],
#  ['wPt-5408', 48.3, '6B'],
#  ['wPt-8412', 48.3, '6B'],
#  ['wPt-5333', 49.5, '6B'],
#  ['wPt-3309', 49.5, '6B'],
#  [306130.0, 51.7, '6B'],
#  [311794.0, 52.0, '6B'],
#  [306653.0, 53.3, '6B'],
#  ['Xgwm508', 53.9, '6B'],
#  ['Xgwm132.2', 54.6, '6B'],
#  [312080.0, 54.6, '6B'],
#  ['wPt-2687', 59.6, '6B'],
#  ['wPt-2479', 59.6, '6B'],
#  [117419.0, 59.9, '6B'],
#  [304979.0, 63.6, '6B'],
#  [312704.0, 63.6, '6B'],
#  [304290.0, 63.6, '6B'],
#  ['Xgwm518', 69.3, '6B'],
#  ['wPt-8721', 72.2, '6B'],
#  ['Xbarc101.2', 77.6, '6B'],
#  ['Xbarc198', 89.9, '6B'],
#  ['Xgwm816', 89.9, '6B'],
#  ['Xgwm193', 91.9, '6B'],
#  ['Xbarc354', 103.7, '6B'],
#  ['wm219', 119.8, '6B'],
#  [311457.0, 124.5, '6B'],
#  ['Xbarc134', 138.7, '6B'],
#  ['wPt-0744', 0.0, '7A'],
#  ['wPt-8418', 0.0, '7A'],
#  [312293.0, 2.0, '7A'],
#  ['wPt-6273', 12.5, '7A'],
#  ['wPt-4172', 12.8, '7A'],
#  ['wPt-1931', 12.8, '7A'],
#  ['wPt-1076', 12.8, '7A'],
#  ['wPt-3836', 12.8, '7A'],
#  ['wPt-7767', 12.8, '7A'],
#  [304060.0, 14.0, '7A'],
#  [306627.0, 20.8, '7A'],
#  ['wPt-9207', 21.5, '7A'],
#  ['Xbarc70', 23.2, '7A'],
#  [306880.0, 56.9, '7A'],
#  ['Xgwm60', 58.4, '7A'],
#  [312493.0, 63.8, '7A'],
#  ['wPt-7734', 65.0, '7A'],
#  ['wPt-9796', 65.0, '7A'],
#  ['wPt-3883', 65.0, '7A'],
#  ['Xwmc283', 65.0, '7A'],
#  ['Xwmc179', 66.6, '7A'],
#  [377900.0, 68.3, '7A'],
#  [306558.0, 73.3, '7A'],
#  [306127.0, 73.6, '7A'],
#  ['Xwmc405.2', 90.2, '7A'],
#  ['Xbarx174', 94.6, '7A'],
#  ['Xgwm276', 0.0, '7A'],
#  ['wPt-6217', 2.0, '7A'],
#  ['wPt-4877', 2.5, '7A'],
#  [305913.0, 0.0, '7A'],
#  [310462.0, 1.7, '7A'],
#  ['Xcfd20', 2.4, '7A'],
#  [304196.0, 3.7, '7A'],
#  ['Xgwm344.1', 6.8, '7A'],
#  ['Xwmc273', 8.9, '7A'],
#  [37439.0, 0.0, '7B'],
#  ['wPt-2283', 0.0, '7B'],
#  [304391.0, 1.3, '7B'],
#  [304747.0, 1.9, '7B'],
#  ['wPt-7975', 4.3, '7B'],
#  ['wPt-6846', 4.3, '7B'],
#  ['wPt-3147', 4.3, '7B'],
#  ['Xwmc323', 9.7, '7B'],
#  ['wPt-7318', 22.3, '7B'],
#  ['wPt-2883', 24.6, '7B'],
#  ['Xwmc405.1', 43.8, '7B'],
#  ['wPt-8283', 44.8, '7B'],
#  ['wPt-1723', 44.8, '7B'],
#  [306452.0, 44.8, '7B'],
#  ['Xwmc182', 58.8, '7B'],
#  ['Xgwm573', 59.7, '7B'],
#  ['Xgwm1184', 68.7, '7B'],
#  ['Xgwm46', 77.8, '7B'],
#  [310076.0, 79.8, '7B'],
#  ['wPt-2737', 81.4, '7B'],
#  ['wPt7934', 95.0, '7B'],
#  ['wPt-6498', 95.0, '7B'],
#  ['Xwmc396', 98.1, '7B'],
#  ['TC74583', 99.7, '7B'],
#  ['Xbarc176', 100.7, '7B'],
#  ['Xbarc278', 114.9, '7B'],
#  ['Xgwm112.1', 118.9, '7B'],
#  ['wPt-4025', 122.6, '7B'],
#  [312270.0, 155.9, '7B'],
#  [305146.0, 162.8, '7B'],
#  [310866.0, 162.8, '7B'],
#  ['wPt-5343', 165.3, '7B'],
#  ['TC69382', 167.3, '7B'],
#  [305954.0, 168.9, '7B'],
#  ['wPt-4814', 169.8, '7B'],
#  ['wPt-0194', 174.4, '7B'],
#  ['wPt-2356', 183.4, '7B'],
#  ['wPt-4300', 184.3, '7B'],
#  ['wPt-3086', 184.3, '7B'],
#  ['Xgwm577', 187.8, '7B'],
#  ['wPt-0217', 189.8, '7B'],
#  [378041.0, 189.8, '7B'],
#  ['wPt-6104', 189.8, '7B'],
#  ['wPt-3939', 190.8, '7B'],
#  ['Xgwm783', 193.3, '7B'],
#  ['Xwmc276', 196.6, '7B'],
#  ['Xbarc340.2', 209.8, '7B'],
#  ['Xgwm146', 212.7, '7B'],
#  [372675.0, 215.4, '7B'],
#  ['wPt-0504', 215.4, '7B'],
#  ['wPt-7219', 215.7, '7B'],
#  ['wPt-6869', 215.7, '7B'],
#  ['Xgwm344.2', 217.2, '7B'],
#  ['wPt-4038', 218.5, '7B'],
#  ['wPt-1085', 218.5, '7B'],
#  [378059.0, 218.8, '7B'],
#  ['wPt-4259', 219.1, '7B'],
#  [312780.0, 220.0, '7B'],
#  [304264.0, 220.0, '7B'],
#  [312227.0, 220.0, '7B'],
#  [304724.0, 221.4, '7B']]

# %%
with open("2008 paper map.csv","w") as outputf:
    for line in allMarker:
        outputf.write(",".join([str(line[0]),str(line[1]),line[2]])+"\n")
